# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Life_Expectancy.csv")
df.head()
# Out:
#        Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0  Afghanistan  Developing              263             62          65
# 1      Albania  Developing                8              0          98
# 2      Algeria  Developing               19             21          95
# 3       Angola  Developing              335             66          64
# 4    Argentina  Developing              116              8          94
#
#    Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV           GDP  \
# 0      1154   19.1                 83      6           65   0.1    584.259210
# 1         0   57.2                  1     98           98   0.1   4575.763787
# 2        63   59.5                 24     95           95   0.1   4132.762920
# 3       118   23.3                 98      7           64   1.9   3695.793748
# 4         0   62.8                  9     93           94   0.1  13467.123600
#
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
#df.info
#info is use for getting information
#df.describe()
# decribe gives 
df.shape
# Out:
# (124, 18)

# %%
sns.scatterplot(x=df["Adult_Mortality"], y=df["Expected"])
# Out:
# <Axes: xlabel='Adult_Mortality', ylabel='Expected'>

# %%
import statsmodels
import statsmodels.api as sm

# %%
x_const = sm.add_constant(x)  # Adds an intercept column to X
x_const.head()
print(x_const.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 x_const = sm.add_constant(x)  # Adds an intercept column to X
#       2 x_const.head()
#       3 print(x_const.head())
#
# NameError: name 'x' is not defined

# %%
x = df["Income_Index"]
y1=df["Expected"]
print(x_const.head())
x_const = sm.add_constant(x)
SLR_model =sm.OLS(y1,x_const).fit()
# .OLS(Ordinary least square) is use for best fit line 
SLR_model.summary()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 x = df["Income_Index"]
#       2 y1=df["Expected"]
#       3 print(x_const.head())
#
# NameError: name 'df' is not defined

# %% [markdown]
# y_pred = SLR_model.predict(x_const)
# y1 = pd.concat([y1,y_pred],axis = 1)
# print(y1.head())

# %%
print(y1.shape, y_pred.shape)
# Out:
# (124, 2) (124,)

# %%
residuals = y1-y_pred
# .pred is use for 
#print(y,y_pred)
#print(residuals)
MSE = np.sum(residuals**2)/len(df)
RMSE = np.sqrt(MSE)
print(RMSE)
# Out:
# 0           11.455023
# 1            0.000000
# 2            0.000000
# 3            0.000000
# 4            0.000000
#               ...
# 120          0.000000
# 121          0.000000
# 122          0.000000
# 123          0.000000
# Expected     0.000000
# Length: 125, dtype: float64
# C:\Users\Peeyush\AppData\Local\Programs\Python\Python313\Lib\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
# Out:
#          Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0    Afghanistan  Developing              263             62          65
# 1        Albania  Developing                8              0          98
# 2        Algeria  Developing               19             21          95
# 3         Angola  Developing              335             66          64
# 4      Argentina  Developing              116              8          94
# ..           ...         ...              ...            ...         ...
# 119    Venezuela  Developing               37             24          95
# 120     Viet Nam  Developing              397             26          89
# 121        Yemen  Developing               48             29          96
# 122       Zambia  Developing              415             31          88
# 123     Zimbabwe  Developing              438             33          85
#
#      Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV  \
# ...
