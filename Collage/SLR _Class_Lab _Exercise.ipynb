# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="15%">
#             <img src="in_class.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> (Week- 1)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the data set 1 (Life Expectancy data)
#
# The dataset contains information about several health and economic factors that contribute to average life expectancy for different countries. <br> Attribute information:
#
# **Country:** Name of the country
#
# **Status:** Whether the country is Developed or Developing
#
# **Adult_Mortality:** Mortality rate for age group 15-60 out of every 1000 individuals of the population
#
# **Infant_Deaths:** Number of infant deaths per 1000 population
#
# **Hepatitis:** Hepatitis B (HepB) immunization coverage for 1 year olds (Percentage)
#
# **Measles:** Number of reported cases for measles per 1000 from population
#
# **BMI:** Average Body Mass Index for entire population
#
# **Underfive_Deaths:** Number of deaths under 5 years of age per 1000 population
#
# **Polio:** Polio (Pol3) immunization coverage for 1 year olds (Percentage)
#
# **Diphtheria:** Diphtheria tetanus toxoid and pertussis (DTP3) immunization coverage for 1 year olds (Percentage)
#
# **HIV:** Deaths per 1000 live births due to HIV/AIDS (0-4 years)
#
# **GDP:** Gross Domestic Product per capita (in USD)
#
# **Population:** Population of the country
#
# **Malnourished10_19:** Prevalence of malnutrition among children and adolescents for Age 10 to 19 (Percentage)
#
# **Malnourished5_9:** Prevalence of malnutrition among children for Age 5 to 9 (Percentage)
#
# **Income_Index:** Human Development Index (HDI) in terms of national income per capita (index ranging from 0 to 1)
#
# **Schooling:** Number of years of Schooling
#
# **Life_Expectancy:** Life Expectancy in age for the country

# %% [markdown]
# ## Table of Content
#
# 1. **[Bivariate Regression](#Bivariate)**
# 2. **[Multiple Linear Regression (MLR)](#MLR)**
# 3. **[Inferences about slope](#ins)**
# 4. **[Model Evaluation](#ML_eval)**
# 5. **[Assumptions of Linear Regression](#assum)**
# 6. **[Model Performance](#ml_perf)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Load the first dataset and check the first five observations
#
# Load the csv file and set the first column as index

# %%
# load the csv file
df = pd.read_csv("Life_Expectancy.csv")
df.head()
# type your code here
# Out:
#        Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0  Afghanistan  Developing              263             62          65
# 1      Albania  Developing                8              0          98
# 2      Algeria  Developing               19             21          95
# 3       Angola  Developing              335             66          64
# 4    Argentina  Developing              116              8          94
#
#    Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV           GDP  \
# 0      1154   19.1                 83      6           65   0.1    584.259210
# 1         0   57.2                  1     98           98   0.1   4575.763787
# 2        63   59.5                 24     95           95   0.1   4132.762920
# 3       118   23.3                 98      7           64   1.9   3695.793748
# 4         0   62.8                  9     93           94   0.1  13467.123600
#
#    Population  Malnourished10_19   Malnourished5_9  Income_Index  Schooling  \
# 0    33736494                17.2             17.3         0.479       10.1
# 1      288914                 1.2              1.3         0.761       14.2
# 2    39871528                 6.0              5.8         0.743       14.4
# 3     2785935                 8.3              8.2         0.531       11.4
# 4    43417765                 1.0              0.9         0.826       17.3
#
#    Expected
# 0      65.0
# 1      77.5
# 2      75.6
# 3      52.4
# 4      76.3

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="Bivariate"> </a>
# ## 1. Bivariate Regression

# %% [markdown]
# ## We shall use the life expectancy dataset

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. How do we analyze the impact of adult mortality rate on average life expectancy of a country?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
#df.shap
#df.info()
#df.describe

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
sns.scatterplot(x=df["Adult_Mortality"],y=df["Expected"])
# Out:
# <Axes: xlabel='Adult_Mortality', ylabel='Expected'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. A regression model is built to check the impact of Human Development Index (Income) on the life expectancy of a nation. What is the expected error value?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import statsmodels 
import statsmodels.api as sm

# %%
df.shape
# Out:
# (124, 18)

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
x=df["Income_Index"]
#print(x)
x_const = sm.add_constant(x)
x_const.head()
print(x_const.head())
# Out:
#    const  Income_Index
# 0    1.0         0.479
# 1    1.0         0.761
# 2    1.0         0.743
# 3    1.0         0.531
# 4    1.0         0.826

# %% [markdown]
# <a id="MLR"> </a>
# ## 2. Multiple Linear Regression(MLR)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Analyze the impact of immunization on life expectancy. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
#so if we have MLR problem we n=know multiplle feature variation
x = df.iloc[:,[4,8,9]]
# iloc mean indexing locking 
y = df['Expected']
x_const = sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Expected   R-squared:                       0.138
# Model:                            OLS   Adj. R-squared:                  0.116
# Method:                 Least Squares   F-statistic:                     6.395
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):           0.000468
# Time:                        17:55:09   Log-Likelihood:                -431.15
# No. Observations:                 124   AIC:                             870.3
# Df Residuals:                     120   BIC:                             881.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const          57.9881      3.524     16.453      0.000      51.010      64.966
# Hepatitis      -0.1037      0.068     -1.528      0.129      -0.238       0.031
# Polio           0.0910      0.043      2.099      0.038       0.005       0.177
# Diphtheria      0.1613      0.082      1.969      0.051      -0.001       0.323
# ==============================================================================
# Omnibus:                        4.513   Durbin-Watson:                   1.000
# Prob(Omnibus):                  0.105   Jarque-Bera (JB):                4.279
# Skew:                          -0.396   Prob(JB):                        0.118
# Kurtosis:                       2.550   Cond. No.                         755.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
y.head()
# Out:
# 0    65.0
# 1    77.5
# 2    75.6
# 3    52.4
# 4    76.3
# Name: Expected, dtype: float64

# %%
# y_pred = SLR_model.predict(x_const) # Predict values of expected by SLR_model
# residuals =

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. If the information that whether the country is a developed or a developing country is included, does it alter the impact of immunzation on life expectancy ?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your c
df.head()
# Out:
#        Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0  Afghanistan  Developing              263             62          65
# 1      Albania  Developing                8              0          98
# 2      Algeria  Developing               19             21          95
# 3       Angola  Developing              335             66          64
# 4    Argentina  Developing              116              8          94
#
#    Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV           GDP  \
# 0      1154   19.1                 83      6           65   0.1    584.259210
# 1         0   57.2                  1     98           98   0.1   4575.763787
# 2        63   59.5                 24     95           95   0.1   4132.762920
# 3       118   23.3                 98      7           64   1.9   3695.793748
# 4         0   62.8                  9     93           94   0.1  13467.123600
#
#    Population  Malnourished10_19   Malnourished5_9  Income_Index  Schooling  \
# 0    33736494                17.2             17.3         0.479       10.1
# 1      288914                 1.2              1.3         0.761       14.2
# 2    39871528                 6.0              5.8         0.743       14.4
# 3     2785935                 8.3              8.2         0.531       11.4
# 4    43417765                 1.0              0.9         0.826       17.3
#
#    Expected
# 0      65.0
# 1      77.5
# 2      75.6
# 3      52.4
# 4      76.3

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
df["Status"].unique()
# Out:
# array(['Developing', 'Developed'], dtype=object)

# %%
df["Status"].unique()
x = df.iloc[:,[4,8,9]]
encod_status = pd.get_dummies(df['Status'],drop_first=1 ,prefix = 'Status' ,dtype = int)
x_encod = pd.concat([x,encod_status] , axis = 1)
x_encod.head()
# Out:
#    Hepatitis   Polio  Diphtheria   Status_Developing
# 0          65      6           65                  1
# 1          98     98           98                  1
# 2          95     95           95                  1
# 3          64      7           64                  1
# 4          94     93           94                  1

# %%
y = df["Expected"]
x_const = sm.add_constant(x_encod)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
# if develong  = 1 exp is decr
# if developing = 0 exp is incr
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Expected   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     14.06
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):           2.00e-09
# Time:                        17:55:10   Log-Likelihood:                -416.35
# No. Observations:                 124   AIC:                             842.7
# Df Residuals:                     119   BIC:                             856.8
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                69.8090      3.771     18.512      0.000      62.342      77.276
# Hepatitis            -0.0035      0.063     -0.056      0.955      -0.128       0.121
# Polio                 0.0771      0.039      1.993      0.049       0.000       0.154
# Diphtheria            0.0456      0.076      0.602      0.548      -0.104       0.196
# Status_Developing   -10.6036      1.872     -5.664      0.000     -14.310      -6.897
# ==============================================================================
# Omnibus:                        2.973   Durbin-Watson:                   1.211
# Prob(Omnibus):                  0.226   Jarque-Bera (JB):                2.635
# Skew:                          -0.355   Prob(JB):                        0.268
# Kurtosis:                       3.077   Cond. No.                         946.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <a id="ins"> </a>
# ## 3. Inferences about slope

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Find the significant variables in the full model when all the variables are considered for prediction of life expectancy.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.head()
# Out:
#        Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0  Afghanistan  Developing              263             62          65
# 1      Albania  Developing                8              0          98
# 2      Algeria  Developing               19             21          95
# 3       Angola  Developing              335             66          64
# 4    Argentina  Developing              116              8          94
#
#    Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV           GDP  \
# 0      1154   19.1                 83      6           65   0.1    584.259210
# 1         0   57.2                  1     98           98   0.1   4575.763787
# 2        63   59.5                 24     95           95   0.1   4132.762920
# 3       118   23.3                 98      7           64   1.9   3695.793748
# 4         0   62.8                  9     93           94   0.1  13467.123600
#
#    Population  Malnourished10_19   Malnourished5_9  Income_Index  Schooling  \
# 0    33736494                17.2             17.3         0.479       10.1
# 1      288914                 1.2              1.3         0.761       14.2
# 2    39871528                 6.0              5.8         0.743       14.4
# 3     2785935                 8.3              8.2         0.531       11.4
# 4    43417765                 1.0              0.9         0.826       17.3
#
#    Expected
# 0      65.0
# 1      77.5
# 2      75.6
# 3      52.4
# 4      76.3

# %%
x = df.drop(['Country','Expected','Status'],axis =1)
y = df['Expected']
# encod_status = pd.get_dummies
encod_status = pd.get_dummies(df['Status'],drop_first=1 ,prefix = 'Status' ,dtype = int)
x_const = sm.add_constant(x_const)
mlrmodel = sm.OLS(y,x_const).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Expected   R-squared:                       0.321
# Model:                            OLS   Adj. R-squared:                  0.298
# Method:                 Least Squares   F-statistic:                     14.06
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):           2.00e-09
# Time:                        17:55:10   Log-Likelihood:                -416.35
# No. Observations:                 124   AIC:                             842.7
# Df Residuals:                     119   BIC:                             856.8
# Df Model:                           4
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                69.8090      3.771     18.512      0.000      62.342      77.276
# Hepatitis            -0.0035      0.063     -0.056      0.955      -0.128       0.121
# Polio                 0.0771      0.039      1.993      0.049       0.000       0.154
# Diphtheria            0.0456      0.076      0.602      0.548      -0.104       0.196
# Status_Developing   -10.6036      1.872     -5.664      0.000     -14.310      -6.897
# ==============================================================================
# Omnibus:                        2.973   Durbin-Watson:                   1.211
# Prob(Omnibus):                  0.226   Jarque-Bera (JB):                2.635
# Skew:                          -0.355   Prob(JB):                        0.268
# Kurtosis:                       3.077   Cond. No.                         946.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Let try to find out which are the insignificant variables
mlr_model.pvalues[mlr_model.pvalues>0.05] # Insignificant variable 
mlr_model.pvalues[mlr_model.pvalues<0.05] # Significant variable
# Out:
# const                7.819796e-37
# Polio                4.856794e-02
# Status_Developing    1.043419e-07
# dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. If economic indices are used to predict the life expectancy, calculate the total variation for the observed values of life expectancy.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
x = df.iloc[:,[11,15]]
y = df['Expected']
x_const = sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
y_pred = mlr_model.predict(x_const)
residual = y-y_pred
print(y,y_pred)
# Out:
# 0      65.0
# 1      77.5
# 2      75.6
# 3      52.4
# 4      76.3
#        ...
# 119    55.3
# 120    53.4
# 121    52.0
# 122    57.0
# 123    48.6
# Name: Expected, Length: 124, dtype: float64 0      62.264429
# 1      73.998340
# 2      73.240868
# 3      64.535391
# 4      77.062897
#          ...
# 119    58.522734
# 120    57.823931
# 121    57.331190
# 122    56.674937
# 123    56.216358
# Length: 124, dtype: float64

# %%
df.shape
# Out:
# (124, 18)

# %%
SST = np.sum((y-y.mean())**2)
SSR = np.sum((y_pred-y.mean())**2)
SSE = np.sum((y-y_pred)**2)
result =  SSR+SSE
print(result)
print(SST,SSR,SSE)
print(mlr_model.summary())
# Out:
# 8819.805483870941
# 8819.805483870969 6292.571603999805 2527.2338798711357
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Expected   R-squared:                       0.713
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     150.6
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):           1.44e-33
# Time:                        17:55:10   Log-Likelihood:                -362.85
# No. Observations:                 124   AIC:                             731.7
# Df Residuals:                     121   BIC:                             740.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           42.6132      1.865     22.848      0.000      38.921      46.306
# GDP           4.515e-05   4.36e-05      1.034      0.303   -4.13e-05       0.000
# Income_Index    40.9705      2.823     14.512      0.000      35.381      46.560
# ==============================================================================
# Omnibus:                        9.157   Durbin-Watson:                   1.349
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               16.954
# Skew:                           0.232   Prob(JB):                     0.000208
# Kurtosis:                       4.751   Cond. No.                     1.05e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.05e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Determine the lower bound and upper bound for estimated value of life expectancy per unit change in HDI (for income)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.head()
# Out:
#        Country      Status  Adult_Mortality  Infant_Deaths  Hepatitis   \
# 0  Afghanistan  Developing              263             62          65
# 1      Albania  Developing                8              0          98
# 2      Algeria  Developing               19             21          95
# 3       Angola  Developing              335             66          64
# 4    Argentina  Developing              116              8          94
#
#    Measles    BMI   Underfive_Deaths   Polio  Diphtheria    HIV           GDP  \
# 0      1154   19.1                 83      6           65   0.1    584.259210
# 1         0   57.2                  1     98           98   0.1   4575.763787
# 2        63   59.5                 24     95           95   0.1   4132.762920
# 3       118   23.3                 98      7           64   1.9   3695.793748
# 4         0   62.8                  9     93           94   0.1  13467.123600
#
#    Population  Malnourished10_19   Malnourished5_9  Income_Index  Schooling  \
# 0    33736494                17.2             17.3         0.479       10.1
# 1      288914                 1.2              1.3         0.761       14.2
# 2    39871528                 6.0              5.8         0.743       14.4
# 3     2785935                 8.3              8.2         0.531       11.4
# 4    43417765                 1.0              0.9         0.826       17.3
#
#    Expected
# 0      65.0
# 1      77.5
# 2      75.6
# 3      52.4
# 4      76.3

# %%
df['Income_Index'].min()
df['Income_Index'].max()
# Out:
# 0.945

# %% [markdown]
# <a id="ML_eval"> </a>
# ## 4. Model Evaluation

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. A model is built to analyze the impact of mortality on Life expectancy. Would the addition of information about population of the country lead to a better prediction?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
x = df.iloc[:,[2,3,7]]
y = df['Expected']
x_const  =sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Expected   R-squared:                       0.530
# Model:                            OLS   Adj. R-squared:                  0.519
# Method:                 Least Squares   F-statistic:                     45.18
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):           1.29e-19
# Time:                        17:55:10   Log-Likelihood:                -393.48
# No. Observations:                 124   AIC:                             795.0
# Df Residuals:                     120   BIC:                             806.2
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                80.3623      1.004     80.060      0.000      78.375      82.350
# Adult_Mortality      -0.0548      0.005     -9.996      0.000      -0.066      -0.044
# Infant_Deaths         0.0905      0.049      1.844      0.068      -0.007       0.188
# Underfive_Deaths     -0.0775      0.038     -2.033      0.044      -0.153      -0.002
# ==============================================================================
# Omnibus:                       54.244   Durbin-Watson:                   1.530
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              142.185
# Skew:                          -1.734   Prob(JB):                     1.33e-31
# Kurtosis:                       6.937   Cond. No.                         392.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X= df.iloc[:,[2,3,7,12]]
y = df['Expected']
x_const  =sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Expected   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     38.99
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):           1.32e-36
# Time:                        17:55:46   Log-Likelihood:                -325.11
# No. Observations:                 124   AIC:                             682.2
# Df Residuals:                     108   BIC:                             727.3
# Df Model:                          15
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 56.6186      3.212     17.628      0.000      50.252      62.985
# Adult_Mortality       -0.0239      0.004     -5.888      0.000      -0.032      -0.016
# Infant_Deaths          0.0556      0.037      1.493      0.138      -0.018       0.129
# Hepatitis              0.0547      0.032      1.734      0.086      -0.008       0.117
# Measles            -7.078e-05   6.11e-05     -1.158      0.249      -0.000    5.04e-05
#  BMI                  -0.0324      0.023     -1.438      0.153      -0.077       0.012
# Underfive_Deaths      -0.0378      0.027     -1.386      0.169      -0.092       0.016
# Polio                 -0.0128      0.022     -0.581      0.562      -0.056       0.031
# Diphtheria            -0.0240      0.040     -0.605      0.546      -0.103       0.055
#  HIV                  -0.9367      0.264     -3.553      0.001      -1.459      -0.414
# GDP                 5.389e-05    3.5e-05      1.539      0.127   -1.55e-05       0.000
# Population         -2.007e-08   8.63e-09     -2.326      0.022   -3.72e-08   -2.97e-09
# Malnourished10_19     -0.5490      0.301     -1.825      0.071      -1.145       0.047
# Malnourished5_9        0.3450      0.285      1.213      0.228      -0.219       0.909
# Income_Index          18.7230      6.372      2.938      0.004       6.093      31.353
# Schooling              0.5395      0.333      1.618      0.109      -0.121       1.200
# ==============================================================================
# Omnibus:                        6.427   Durbin-Watson:                   1.717
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):               10.884
# Skew:                           0.015   Prob(JB):                      0.00433
# Kurtosis:                       4.451   Cond. No.                     9.13e+08
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.13e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Fit a full model and test the significance of the overall model. <br></b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
x = df.drop(['Country','Expected','Status'],axis = 1)
y = df['Expected']
encod_status = pd.get_dummies(df['Status'],drop_first=1,prefix='Status',dtype=int)
x_encod = pd.concat([X,encod_status],axis=1)
x_const = sm.add_constant(x_encod)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
mlr_model.f_pvalue
# H0: the model is insignificant 
# H1: the model is significant
# if p vakue is less than alpha we reject null hypthioese alpha = 0.05
# Out:
# np.float64(3.8930379802067545e-22)

# %% [markdown]
# <a id="assum"> </a>
# ## 4. Assumptions of Linear Regression

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. A model is built using all the features (full model) to predict the life expectancy. Check whether the residuals obtained form the model follow a normal distribution.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from scipy import stats
from scipy.stats import shapiro

# %%
# type your code here
x = df.drop(['Country','Expected','Status'],axis = 1)
y = df['Expected']
encod_status = pd.get_dummies(df['Status'],drop_first=1,prefix='Status',dtype=int)
x_encod = pd.concat([x,encod_status],axis=1)
x_const = sm.add_constant(x_encod)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
stats,pvalue = shapiro(mlr_model.resid)
print('test Statistics:',stats)
print('pvalue',pvalue)
# So pvalue < alpha so we reject null hupythesis
# Out:
# test Statistics: 0.9769424921513372
# pvalue 0.03209218431928859

# %%
sns.distplot(mlr_model.resid)
# Out:
# /tmp/ipykernel_21254/160148319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mlr_model.resid)
# <Axes: ylabel='Density'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                         <b>11. Does the interaction of status of the country and its GDP have significant effect on life expectancy? (consider the full model)</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Adult_Mortality', 'Infant_Deaths', 'Hepatitis ',
#        'Measles ', ' BMI ', 'Underfive_Deaths ', 'Polio', 'Diphtheria ',
#        ' HIV', 'GDP', 'Population', 'Malnourished10_19 ', 'Malnourished5_9',
#        'Income_Index', 'Schooling', 'Expected'],
#       dtype='object')

# %%
x = df.iloc[:,11]
y = df['Expected']
encod_status = pd.get_dummies(df['Status'],drop_first=1,prefix='Status',dtype=int)
x_encod = pd.concat([x,encod_status],axis=1)
x_encod.head()
x_encod['interaction'] = x_encod['Status_Developing']*x_encod['GDP']
x_encod.head()

y = df['Expected']
x_const = sm.add_constant(x_encod)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Expected   R-squared:                       0.423
# Model:                            OLS   Adj. R-squared:                  0.408
# Method:                 Least Squares   F-statistic:                     29.30
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):           2.76e-14
# Time:                        17:56:35   Log-Likelihood:                -406.27
# No. Observations:                 124   AIC:                             820.5
# Df Residuals:                     120   BIC:                             831.8
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const                80.9524      1.990     40.675      0.000      77.012      84.893
# GDP                1.283e-05   8.43e-05      0.152      0.879      -0.000       0.000
# Status_Developing   -14.0075      2.130     -6.576      0.000     -18.225      -9.790
# interaction           0.0005      0.000      3.961      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                        4.249   Durbin-Watson:                   1.481
# Prob(Omnibus):                  0.119   Jarque-Bera (JB):                3.697
# Skew:                          -0.398   Prob(JB):                        0.157
# Kurtosis:                       3.286   Cond. No.                     7.14e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.14e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Construct a full no-intecept model. What would you conclude when all the variables take value 0? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x = df.drop(['Country','Expected','Status'],axis = 1)
y = df['Expected']
encod_status = pd.get_dummies(df['Status'],drop_first=1,prefix='Status',dtype=int)
x_encod = pd.concat([x,encod_status],axis=1)
mlr_model = sm.OLS(y,x_encod).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               Expected   R-squared (uncentered):                   0.993
# Model:                            OLS   Adj. R-squared (uncentered):              0.992
# Method:                 Least Squares   F-statistic:                              940.0
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):                   4.84e-108
# Time:                        17:56:37   Log-Likelihood:                         -399.28
# No. Observations:                 124   AIC:                                      830.6
# Df Residuals:                     108   BIC:                                      875.7
# Df Model:                          16
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Adult_Mortality       -0.0069      0.007     -0.960      0.339      -0.021       0.007
# Infant_Deaths         -0.0807      0.066     -1.224      0.223      -0.211       0.050
# Hepatitis              0.0305      0.058      0.523      0.602      -0.085       0.146
# Measles               -0.0002      0.000     -1.516      0.133      -0.000    5.18e-05
#  BMI                  -0.0697      0.041     -1.696      0.093      -0.151       0.012
# Underfive_Deaths       0.0712      0.048      1.482      0.141      -0.024       0.166
# Polio                  0.0180      0.040      0.449      0.654      -0.061       0.097
# Diphtheria             0.0388      0.073      0.535      0.593      -0.105       0.183
#  HIV                   0.5728      0.455      1.258      0.211      -0.330       1.475
# GDP                -3.684e-05    6.3e-05     -0.585      0.560      -0.000    8.81e-05
# Population         -1.747e-08   1.58e-08     -1.107      0.271   -4.87e-08    1.38e-08
# Malnourished10_19     -1.1120      0.546     -2.035      0.044      -2.195      -0.029
# Malnourished5_9        1.6540      0.496      3.334      0.001       0.671       2.637
# Income_Index          43.2384     11.241      3.846      0.000      20.956      65.520
# Schooling              2.1667      0.601      3.608      0.000       0.976       3.357
# Status_Developing      7.8535      1.821      4.313      0.000       4.244      11.463
# ==============================================================================
# Omnibus:                        7.813   Durbin-Watson:                   1.591
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                7.565
# Skew:                           0.588   Prob(JB):                       0.0228
# Kurtosis:                       3.282   Cond. No.                     8.75e+08
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 8.75e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Hereon on we shall consider the FEV dataset.

# %% [markdown]
# ### About the data set (Respiratory function data)
#
# Dataset consists of information about respiratory function in children and adolescents and factors that might impact the respiratory function. <br> Attribute information:
#
# **Age:** Age in years
#
# **Height:** Height in inches
#
# **Gender:** Gender value is 1 if male 0 if female
#
# **Smoke:** Whether the person is a smoker or non- smoker, the value is 1 if smoker and 0 otherwise
#
# **FEV:**  Forced Exhalation Volume (FEV), a measure of how much air somebody can forcibly exhale from their lung (Percentage)

# %% [markdown]
# #### Load the dataset and check the first five observations

# %%
# load the csv file
# type your code here
df =pd.read_csv('LungCapdata.csv')
df.head()
# Out:
#    Age  Height  Gender  Smoke    FEV
# 0    9    57.0       0      0  1.708
# 1    8    67.5       0      0  1.724
# 2    7    54.5       0      0  1.720
# 3    9    53.0       1      0  1.558
# 4    9    57.0       1      0  1.895

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Can we use a linear regression model to analyze the impact of all the features on respiratory function (FEV) ? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
df.shape
# Out:
# (654, 5)

# %%
x = df.drop('FEV',axis=1)
y=df['FEV']
x_const = sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    FEV   R-squared:                       0.775
# Model:                            OLS   Adj. R-squared:                  0.774
# Method:                 Least Squares   F-statistic:                     560.0
# Date:                Wed, 09 Sep 2026   Prob (F-statistic):          9.10e-209
# Time:                        17:56:42   Log-Likelihood:                -345.90
# No. Observations:                 654   AIC:                             701.8
# Df Residuals:                     649   BIC:                             724.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.4570      0.223    -20.001      0.000      -4.895      -4.019
# Age            0.0655      0.009      6.904      0.000       0.047       0.084
# Height         0.1042      0.005     21.901      0.000       0.095       0.114
# Gender         0.1571      0.033      4.731      0.000       0.092       0.222
# Smoke         -0.0872      0.059     -1.472      0.141      -0.204       0.029
# ==============================================================================
# Omnibus:                       22.758   Durbin-Watson:                   1.645
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               43.271
# Skew:                           0.207   Prob(JB):                     4.02e-10
# Kurtosis:                       4.190   Cond. No.                         861.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. How can we rectify the multicollinearity detected in question 13? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
plt.subplots(figsize = (5,3))
sns.heatmap(df.corr(),annot = True,annot_kws={'size':10})
# Out:
# <Axes: >

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. A Linear regression model is used to analyze the impact of all possible features on respiratory function (FEV). How do we check whether or not the model adequately captures the relationship between the response and predictor variables?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df.columns
# Out:
# Index(['Age', 'Height', 'Gender', 'Smoke', 'FEV'], dtype='object')

# %%
x.shape
# Out:
# (654, 4)

# %%
x = df.iloc[:,:-1]
vif = pd.DataFrame()
vif['VIF_Factor'] = [variance_inflation_factor(x.values,i) for i in range (x.shape[1])]
vif['Featues'] = x.columns
print(vif)
# x.value
# vif
# Out:
#    VIF_Factor Featues
# 0   24.322098     Age
# 1   24.524524  Height
# 2    2.130851  Gender
# 3    1.342164   Smoke

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16.  A Linear regression model is used to analyze the impact of all possible features on respiratory function (FEV). Check whether the error terms are serially independent?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
import statsmodels.stats.api as sms

# %%
df.columns
# Out:
# Index(['Age', 'Height', 'Gender', 'Smoke', 'FEV'], dtype='object')

# %%
x = df.drop(['Height','FEV'],axis=1)
y=df['FEV']
x_const = sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
y_pred = mlr_model.predict(x_const)
residual = y - y_pred

sms.durbin_watson(residual)
# We can say somewhat positive Autocorrelation
# Out:
# np.float64(1.5969678178341278)

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. A model is built using all the features to predict the FEV. Check whether the residuals obtained form the model are normally distributed. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from scipy import stats
from scipy.stats import shapiro

# %%
x = df.drop(['Height','FEV'],axis=1)
y=df['FEV']
x_const = sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
y_pred = mlr_model.predict(x_const)
stat , pvalue = shapiro(mlr_model.resid)
print('Test Statistics:',stat)
print('pvalue',pvalue)
# Out:
# Test Statistics: 0.9910871570512472
# pvalue 0.0005548031017414689

# %%
sns.distplot(mlr_model.resid)
# Out:
# /tmp/ipykernel_21254/160148319.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(mlr_model.resid)
# <Axes: ylabel='Density'>

# %% [markdown]
# <a id="ml_perf"> </a>
# ## 6. Model Performance

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. Consider the full model. Calculate the mean square error and the root mean square error.</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
x = df.drop(['FEV'],axis=1)
y=df['FEV']
x_const = sm.add_constant(x)
mlr_model = sm.OLS(y,x_const).fit()
mlr_model.summary()
y_pred = mlr_model.predict(x_const)
residual = (y-y_pred)

# %%
MSE = np.sum(residual**2)/len(df)
RMSE  = np.sqrt(MSE)
print(MSE,RMSE)
# Out:
# 0.16862317131301385 0.4106375181507577

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. Calculate the mean absolute error and the  mean absolute percentage error. Compare the values of RMSE and MAE. </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
MAE = np.sum(abs(residual))/len(df)
MAPE = (np.sum(abs(residual/y))/len(df))*100
print(MAE,MAPE)
# Out:
# 0.3130464419754906 12.570875467147197

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Consider the full model, has the model overfitted? </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(['FEV'],axis=1)
y=df['FEV']
x_train , x_test , y_train ,y_test = train_test_split(x,y,random_state=1,test_size=0.3)
# Trainigng the model oin train dataset
x_const = sm.add_constant(x_train)
model_train = sm.OLS(y_train,x_const).fit()
print('Model_train : ',model_train.rsquared)

# Testing the model no test dataset
x_const = sm.add_constant(x_test)
model_test = sm.OLS(y_test ,x_const).fit()
print('Model_test :',model_test.rsquared)

#  Robust model no over fitting
# Out:
# Model_train :  0.7822757192137579
# Model_test : 0.7592423771703153
