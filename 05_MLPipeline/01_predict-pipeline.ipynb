# %% [markdown]
# # Predict `with` using ML Pipeline

# %%
import numpy as np

# %%
import pickle
import joblib

# Solution 1: Try using joblib instead of pickle (recommended for scikit-learn models)
try:
    with open('pipe.pkl', 'rb') as file:
        pipe = joblib.load(file)
    print("Model loaded successfully with joblib!")
except Exception as e:
    print(f"Joblib loading failed: {e}")
    
    # Solution 2: Try loading with pickle but handle the version compatibility
    try:
        import sklearn
        print(f"Current scikit-learn version: {sklearn.__version__}")
        
        # Load with pickle and handle potential compatibility issues
        with open('pipe.pkl', 'rb') as file:
            pipe = pickle.load(file)
        print("Model loaded successfully with pickle!")
        
    except ValueError as ve:
        print(f"Version compatibility error: {ve}")
        print("\nSuggested solutions:")
        print("1. Recreate the model with your current scikit-learn version")
        print("2. Downgrade scikit-learn to match the version used to create the pickle")
        print("3. Use joblib.load() instead of pickle.load() for scikit-learn models")
        
    except Exception as e:
        print(f"Other error occurred: {e}")
# Out:
# Joblib loading failed: node array from the pickle has an incompatible dtype:
# - expected: {'names': ['left_child', 'right_child', 'feature', 'threshold', 'impurity', 'n_node_samples', 'weighted_n_node_samples', 'missing_go_to_left'], 'formats': ['<i8', '<i8', '<i8', '<f8', '<f8', '<i8', '<f8', 'u1'], 'offsets': [0, 8, 16, 24, 32, 40, 48, 56], 'itemsize': 64}
# - got     : [('left_child', '<i8'), ('right_child', '<i8'), ('feature', '<i8'), ('threshold', '<f8'), ('impurity', '<f8'), ('n_node_samples', '<i8'), ('weighted_n_node_samples', '<f8')]
# Current scikit-learn version: 1.7.2
# Version compatibility error: node array from the pickle has an incompatible dtype:
# - expected: {'names': ['left_child', 'right_child', 'feature', 'threshold', 'impurity', 'n_node_samples', 'weighted_n_node_samples', 'missing_go_to_left'], 'formats': ['<i8', '<i8', '<i8', '<f8', '<f8', '<i8', '<f8', 'u1'], 'offsets': [0, 8, 16, 24, 32, 40, 48, 56], 'itemsize': 64}
# ...

# %%
pipe.predict(test_input2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pipe.predict(test_input2)
#
# NameError: name 'pipe' is not defined

# %% [markdown]
# # Predict `without` using ML Pipeline

# %%
import pickle
import numpy as np

# %%
ohe_sex = pickle.load(open('models/ohe_sex.pkl','rb'))
ohe_embarked = pickle.load(open('models/ohe_embarked.pkl','rb'))
clf = pickle.load(open('models/clf.pkl','rb'))

# %%
# Assume user input
# Pclass/gender/age/SibSp/Parch/Fare/Embarked
test_input = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
test_input
# Out:
# array([[2, 'male', 31.0, 0, 0, 10.5, 'S']], dtype=object)

# %%
test_input_sex = ohe_sex.transform(test_input[:,1].reshape(1,1))
# Out:
# /home/peeyush/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_sex
# Out:
# array([[0., 1.]])

# %%
test_input_embarked = ohe_embarked.transform(test_input[:,-1].reshape(1,1))

# %%
test_input_embarked
# Out:
# array([[0., 0., 1.]])

# %%
test_input_age = test_input[:,2].reshape(1,1)

# %%
test_input_transformed = np.concatenate((test_input[:,[0,3,4,5]],test_input_age,test_input_sex,test_input_embarked),axis=1)

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %%
clf.predict(test_input_transformed)
# Out:
# array([1])
